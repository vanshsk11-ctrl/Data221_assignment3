# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
#Load the dataset and clean the data
kidney_df = pd.read_csv("kidney_disease.csv")
kidney_df["classification"] = kidney_df["classification"].str.strip()

# %%
#Creates feature matrix X which is every column except "classification" than fills all the missing values of each feature column with their respective medians
#Create a vector which is the "classification" column
X = kidney_df.drop("classification", axis=1)
y = kidney_df["classification"]

X = X.select_dtypes(include="number")
X = X.fillna(X.median())

# %%
#Splits the model 70% of it is training data, and the remaining 30% is the testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=25)

print(f"Training samples: {len(X_train)}")
print(f"Testing samples: {len(X_test)}")
# Out:
# Training samples: 280
# Testing samples: 120

# %%
'''
If we train and test the model using the same data, we cannot validate the model and cannot see if the model is making accurate predictions since it already knows exactly where to map the data too

The purpose of a testing set is to validate the model and see how accurate the model is, since we can see how the predicted data matches to the actual data. From here we can compute the MAE(Mean absolute error) which is the average difference between the predicted and actual data.
'''
# Out:
# '\nIf we train and test the model using the same data, we cannot validate the model and cannot see if the model is making accurate predictions since it already knows exactly where to map the data too\n\nThe purpose of a testing set is to validate the model and see how accurate the model is, since we can see how the predicted data matches to the actual data. From here we can compute the MAE(Mean absolute error) which is the average difference between the predicted and actual data.\n'
